# %%
"""

[Başla]
   │
   ▼
[Gerekli Kütüphaneleri Yükle]
   │
   ▼
[Bankacılık Mesajlarını Yükle]
   │
   ▼
[Veriyi Etiketle: SAFE / FRAUD]
   │
   ▼
[Train / Test Ayrımı]
   │
   ▼
[Metni Sayısallaştır (TF-IDF)]
   │
   ▼
[Random Forest Modelini Eğit]
   │
   ▼
[Tahmin Motoru Oluştur]
   │
   ▼
──────────── AI TESTING KATMANI ────────────
   │
   ├──► [Adversarial Test]
   │        Manipüle edilmiş metinler
   │
   ├──► [Semantic Test]
   │        False positive kontrolü
   │
   ├──► [OOD Test]
   │        Anlamsız / kapsam dışı veri
   │
   └──► [Stealth Fraud Test]
            Resmi dil ile gizlenmiş saldırı
   │
   ▼
[Model Tahminleri + Güven Skoru]
   │
   ▼
[Confusion Matrix & Metrikler]
   │
   ▼
[Hata Analizi]
   │
   ▼
[Bitiş]

"""
